# %%
# Global Fuel Price Data set

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("fuel_price.csv")

# %%
df.head(5)
# Out:
#          date        country         region income_level subsidy_level  \
# 0  2020-01-06  United States  North America         High           Low
# 1  2020-01-13  United States  North America         High           Low
# 2  2020-01-20  United States  North America         High           Low
# 3  2020-01-27  United States  North America         High           Low
# 4  2020-02-03  United States  North America         High           Low
#
#    petrol_usd_liter  diesel_usd_liter  lpg_usd_liter  brent_crude_usd  \
# 0             1.465             1.289          1.093            65.75
# 1             1.435             1.319          1.077            65.54
# 2             1.446             1.329          1.080            66.51
# 3             1.488             1.359          1.125            68.79
# 4             1.457             1.341          1.111            68.44
#
#    tax_percentage
# 0            59.6
# 1            27.6
# 2            62.3
# 3            44.8
# 4            51.4

# %%
df.tail(5)
# Out:
#              date country  region income_level subsidy_level  \
# 27463  2026-03-09  Rwanda  Africa          Low           Low
# 27464  2026-03-16  Rwanda  Africa          Low           Low
# 27465  2026-03-23  Rwanda  Africa          Low           Low
# 27466  2026-03-30  Rwanda  Africa          Low           Low
# 27467  2026-04-06  Rwanda  Africa          Low           Low
#
#        petrol_usd_liter  diesel_usd_liter  lpg_usd_liter  brent_crude_usd  \
# 27463             3.036             2.849          2.294            130.0
# 27464             3.020             2.861          2.248            130.0
# 27465             3.072             2.825          2.334            130.0
# 27466             3.045             2.816          2.282            130.0
# 27467             3.064             2.846          2.296            130.0
#
#        tax_percentage
# 27463            62.3
# 27464            43.3
# 27465            64.1
# 27466            43.7
# 27467            63.7

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27468 entries, 0 to 27467
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   date              27468 non-null  object
#  1   country           27468 non-null  object
#  2   region            27468 non-null  object
#  3   income_level      27468 non-null  object
#  4   subsidy_level     27468 non-null  object
#  5   petrol_usd_liter  27468 non-null  float64
#  6   diesel_usd_liter  27468 non-null  float64
#  7   lpg_usd_liter     27468 non-null  float64
#  8   brent_crude_usd   27468 non-null  float64
#  9   tax_percentage    27468 non-null  float64
# dtypes: float64(5), object(5)
# memory usage: 2.1+ MB

# %%
df.describe
# Out:
# <bound method NDFrame.describe of              date        country         region income_level subsidy_level  \
# 0      2020-01-06  United States  North America         High           Low
# 1      2020-01-13  United States  North America         High           Low
# 2      2020-01-20  United States  North America         High           Low
# 3      2020-01-27  United States  North America         High           Low
# 4      2020-02-03  United States  North America         High           Low
# ...           ...            ...            ...          ...           ...
# 27463  2026-03-09         Rwanda         Africa          Low           Low
# 27464  2026-03-16         Rwanda         Africa          Low           Low
# 27465  2026-03-23         Rwanda         Africa          Low           Low
# 27466  2026-03-30         Rwanda         Africa          Low           Low
# 27467  2026-04-06         Rwanda         Africa          Low           Low
#
# ...

# %%
df.describe()
# Out:
#        petrol_usd_liter  diesel_usd_liter  lpg_usd_liter  brent_crude_usd  \
# count      27468.000000      27468.000000   27468.000000     27468.000000
# mean           2.281915          2.133760       1.711473       106.686453
# std            1.540612          1.465058       1.155543        18.972391
# min            0.010000          0.010000       0.010000        47.970000
# 25%            0.926000          0.858000       0.695000       101.140000
# 50%            2.116500          1.954500       1.588000       112.270000
# 75%            3.457000          3.231000       2.590000       119.410000
# max            6.779000          6.240000       5.100000       130.000000
#
#        tax_percentage
# count    27468.000000
# mean        26.774468
# std         17.203349
# min          0.000000
# 25%         13.500000
# 50%         23.400000
# 75%         38.900000
# max         65.000000

# %%
df.count()
# Out:
# date                27468
# country             27468
# region              27468
# income_level        27468
# subsidy_level       27468
# petrol_usd_liter    27468
# diesel_usd_liter    27468
# lpg_usd_liter       27468
# brent_crude_usd     27468
# tax_percentage      27468
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27468 entries, 0 to 27467
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   date              27468 non-null  object
#  1   country           27468 non-null  object
#  2   region            27468 non-null  object
#  3   income_level      27468 non-null  object
#  4   subsidy_level     27468 non-null  object
#  5   petrol_usd_liter  27468 non-null  float64
#  6   diesel_usd_liter  27468 non-null  float64
#  7   lpg_usd_liter     27468 non-null  float64
#  8   brent_crude_usd   27468 non-null  float64
#  9   tax_percentage    27468 non-null  float64
# dtypes: float64(5), object(5)
# memory usage: 2.1+ MB

# %%
df.country.count
# Out:
# <bound method Series.count of 0        United States
# 1        United States
# 2        United States
# 3        United States
# 4        United States
#              ...
# 27463           Rwanda
# 27464           Rwanda
# 27465           Rwanda
# 27466           Rwanda
# 27467           Rwanda
# Name: country, Length: 27468, dtype: object>

# %%
df.columns
# Out:
# Index(['date', 'country', 'region', 'income_level', 'subsidy_level',
#        'petrol_usd_liter', 'diesel_usd_liter', 'lpg_usd_liter',
#        'brent_crude_usd', 'tax_percentage'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=27468, step=1)

# %%
df["petrol_usd_liter"].max()
# Out:
# 6.779

# %%
df["country"].unique()
# Out:
# array(['United States', 'Canada', 'Mexico', 'Brazil', 'Argentina',
#        'Colombia', 'Chile', 'Peru', 'Venezuela', 'Ecuador',
#        'United Kingdom', 'Germany', 'France', 'Italy', 'Spain',
#        'Netherlands', 'Belgium', 'Sweden', 'Norway', 'Denmark', 'Finland',
#        'Poland', 'Portugal', 'Greece', 'Switzerland', 'Austria',
#        'Ireland', 'Hungary', 'Czech Republic', 'Romania', 'Russia',
#        'Ukraine', 'Turkey', 'China', 'Japan', 'South Korea', 'India',
#        'Indonesia', 'Malaysia', 'Thailand', 'Vietnam', 'Philippines',
#        'Bangladesh', 'Pakistan', 'Sri Lanka', 'Nepal', 'Myanmar',
#        'Singapore', 'Hong Kong', 'Taiwan', 'Australia', 'New Zealand',
#        'Saudi Arabia', 'UAE', 'Kuwait', 'Qatar', 'Iran', 'Iraq', 'Israel',
#        'Jordan', 'Lebanon', 'Egypt', 'South Africa', 'Nigeria', 'Kenya',
#        'Ethiopia', 'Ghana', 'Tanzania', 'Morocco', 'Algeria', 'Libya',
#        'Tunisia', 'Angola', 'Mozambique', 'Zambia', 'Zimbabwe', 'Uganda',
# ...

# %%
vc = df["country"].value_counts()

print("Top Country:", vc.idxmax())
print("Count:", vc.max())
# Out:
# Top Country: United States
# Count: 327

# %%
df.isnull().sum()
# Out:
# date                0
# country             0
# region              0
# income_level        0
# subsidy_level       0
# petrol_usd_liter    0
# diesel_usd_liter    0
# lpg_usd_liter       0
# brent_crude_usd     0
# tax_percentage      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.copy()
# Out:
#              date        country         region income_level subsidy_level  \
# 0      2020-01-06  United States  North America         High           Low
# 1      2020-01-13  United States  North America         High           Low
# 2      2020-01-20  United States  North America         High           Low
# 3      2020-01-27  United States  North America         High           Low
# 4      2020-02-03  United States  North America         High           Low
# ...           ...            ...            ...          ...           ...
# 27463  2026-03-09         Rwanda         Africa          Low           Low
# 27464  2026-03-16         Rwanda         Africa          Low           Low
# 27465  2026-03-23         Rwanda         Africa          Low           Low
# 27466  2026-03-30         Rwanda         Africa          Low           Low
# 27467  2026-04-06         Rwanda         Africa          Low           Low
#
# ...

# %%
df1=df

# %%
print(df1)
# Out:
#              date        country         region income_level subsidy_level  \
# 0      2020-01-06  United States  North America         High           Low
# 1      2020-01-13  United States  North America         High           Low
# 2      2020-01-20  United States  North America         High           Low
# 3      2020-01-27  United States  North America         High           Low
# 4      2020-02-03  United States  North America         High           Low
# ...           ...            ...            ...          ...           ...
# 27463  2026-03-09         Rwanda         Africa          Low           Low
# 27464  2026-03-16         Rwanda         Africa          Low           Low
# 27465  2026-03-23         Rwanda         Africa          Low           Low
# 27466  2026-03-30         Rwanda         Africa          Low           Low
# 27467  2026-04-06         Rwanda         Africa          Low           Low
#
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27468 entries, 0 to 27467
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   date              27468 non-null  object
#  1   country           27468 non-null  object
#  2   region            27468 non-null  object
#  3   income_level      27468 non-null  object
#  4   subsidy_level     27468 non-null  object
#  5   petrol_usd_liter  27468 non-null  float64
#  6   diesel_usd_liter  27468 non-null  float64
#  7   lpg_usd_liter     27468 non-null  float64
#  8   brent_crude_usd   27468 non-null  float64
#  9   tax_percentage    27468 non-null  float64
# dtypes: float64(5), object(5)
# memory usage: 2.1+ MB

# %%
df.loc[5]
# Out:
# date                   2020-02-10
# country             United States
# region              North America
# income_level                 High
# subsidy_level                 Low
# petrol_usd_liter            1.461
# diesel_usd_liter            1.356
# lpg_usd_liter               1.105
# brent_crude_usd             68.09
# tax_percentage               15.0
# Name: 5, dtype: object

# %%
print(df.loc[0])
# Out:
# date                   2020-01-06
# country             United States
# region              North America
# income_level                 High
# subsidy_level                 Low
# petrol_usd_liter            1.465
# diesel_usd_liter            1.289
# lpg_usd_liter               1.093
# brent_crude_usd             65.75
# tax_percentage               59.6
# Name: 0, dtype: object

# %%
df.iloc[0]
# Out:
# date                   2020-01-06
# country             United States
# region              North America
# income_level                 High
# subsidy_level                 Low
# petrol_usd_liter            1.465
# diesel_usd_liter            1.289
# lpg_usd_liter               1.093
# brent_crude_usd             65.75
# tax_percentage               59.6
# Name: 0, dtype: object

# %%
df.iloc[0,3]
# Out:
# 'High'

# %%
df.info
# Out:
# <bound method DataFrame.info of              date        country         region income_level subsidy_level  \
# 0      2020-01-06  United States  North America         High           Low
# 1      2020-01-13  United States  North America         High           Low
# 2      2020-01-20  United States  North America         High           Low
# 3      2020-01-27  United States  North America         High           Low
# 4      2020-02-03  United States  North America         High           Low
# ...           ...            ...            ...          ...           ...
# 27463  2026-03-09         Rwanda         Africa          Low           Low
# 27464  2026-03-16         Rwanda         Africa          Low           Low
# 27465  2026-03-23         Rwanda         Africa          Low           Low
# 27466  2026-03-30         Rwanda         Africa          Low           Low
# 27467  2026-04-06         Rwanda         Africa          Low           Low
#
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27468 entries, 0 to 27467
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   date              27468 non-null  object
#  1   country           27468 non-null  object
#  2   region            27468 non-null  object
#  3   income_level      27468 non-null  object
#  4   subsidy_level     27468 non-null  object
#  5   petrol_usd_liter  27468 non-null  float64
#  6   diesel_usd_liter  27468 non-null  float64
#  7   lpg_usd_liter     27468 non-null  float64
#  8   brent_crude_usd   27468 non-null  float64
#  9   tax_percentage    27468 non-null  float64
# dtypes: float64(5), object(5)
# memory usage: 2.1+ MB

# %%
df1["date"] = pd.to_datetime(df1["date"])

# %%
df1["date"]=df1["date"].astype("int64")

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27468 entries, 0 to 27467
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   date              27468 non-null  int64
#  1   country           27468 non-null  object
#  2   region            27468 non-null  object
#  3   income_level      27468 non-null  object
#  4   subsidy_level     27468 non-null  object
#  5   petrol_usd_liter  27468 non-null  float64
#  6   diesel_usd_liter  27468 non-null  float64
#  7   lpg_usd_liter     27468 non-null  float64
#  8   brent_crude_usd   27468 non-null  float64
#  9   tax_percentage    27468 non-null  float64
# dtypes: float64(5), int64(1), object(4)
# memory usage: 2.1+ MB

# %%
df1["subsidy_level"].unique()
# Out:
# array(['Low', 'High', 'Medium', 'Very High'], dtype=object)

# %%
df1["subsidy_level"] = df1["subsidy_level"].map({
    "Low": 1,
    "Medium": 2,
    "High": 3,
    "Very High" : 4
})

# %%
# df["subsidy_level"].dtype()

# %%
df["subsidy_level"].unique()
# Out:
# array([1, 3, 2, 4], dtype=int64)

# %%
df1.sort_values(["income_level","country"])
# Out:
#                       date    country   region income_level  subsidy_level  \
# 16350  1578268800000000000  Australia  Oceania         High              1
# 16351  1578873600000000000  Australia  Oceania         High              1
# 16352  1579478400000000000  Australia  Oceania         High              1
# 16353  1580083200000000000  Australia  Oceania         High              1
# 16354  1580688000000000000  Australia  Oceania         High              1
# ...                    ...        ...      ...          ...            ...
# 13402  1773014400000000000    Vietnam     Asia       Middle              2
# 13403  1773619200000000000    Vietnam     Asia       Middle              2
# 13404  1774224000000000000    Vietnam     Asia       Middle              2
# 13405  1774828800000000000    Vietnam     Asia       Middle              2
# 13406  1775433600000000000    Vietnam     Asia       Middle              2
#
# ...

# %%
df1.sort_index()
# Out:
#                       date        country         region income_level  \
# 0      1578268800000000000  United States  North America         High
# 1      1578873600000000000  United States  North America         High
# 2      1579478400000000000  United States  North America         High
# 3      1580083200000000000  United States  North America         High
# 4      1580688000000000000  United States  North America         High
# ...                    ...            ...            ...          ...
# 27463  1773014400000000000         Rwanda         Africa          Low
# 27464  1773619200000000000         Rwanda         Africa          Low
# 27465  1774224000000000000         Rwanda         Africa          Low
# 27466  1774828800000000000         Rwanda         Africa          Low
# 27467  1775433600000000000         Rwanda         Africa          Low
#
#        subsidy_level  petrol_usd_liter  diesel_usd_liter  lpg_usd_liter  \
# ...

# %%
df1.rename(columns={"date": "Date"}, inplace=True)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27468 entries, 0 to 27467
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date              27468 non-null  int64
#  1   country           27468 non-null  object
#  2   region            27468 non-null  object
#  3   income_level      27468 non-null  object
#  4   subsidy_level     27468 non-null  int64
#  5   petrol_usd_liter  27468 non-null  float64
#  6   diesel_usd_liter  27468 non-null  float64
#  7   lpg_usd_liter     27468 non-null  float64
#  8   brent_crude_usd   27468 non-null  float64
#  9   tax_percentage    27468 non-null  float64
# dtypes: float64(5), int64(2), object(3)
# memory usage: 2.1+ MB

# %%
# df1 = df1[["country" , "Date" , "income_level"]]

# %%
# df1.info()

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27468 entries, 0 to 27467
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date              27468 non-null  int64
#  1   country           27468 non-null  object
#  2   region            27468 non-null  object
#  3   income_level      27468 non-null  object
#  4   subsidy_level     27468 non-null  int64
#  5   petrol_usd_liter  27468 non-null  float64
#  6   diesel_usd_liter  27468 non-null  float64
#  7   lpg_usd_liter     27468 non-null  float64
#  8   brent_crude_usd   27468 non-null  float64
#  9   tax_percentage    27468 non-null  float64
# dtypes: float64(5), int64(2), object(3)
# memory usage: 2.1+ MB

# %%
df1_backup = df1.copy()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27468 entries, 0 to 27467
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date              27468 non-null  int64
#  1   country           27468 non-null  object
#  2   region            27468 non-null  object
#  3   income_level      27468 non-null  object
#  4   subsidy_level     27468 non-null  int64
#  5   petrol_usd_liter  27468 non-null  float64
#  6   diesel_usd_liter  27468 non-null  float64
#  7   lpg_usd_liter     27468 non-null  float64
#  8   brent_crude_usd   27468 non-null  float64
#  9   tax_percentage    27468 non-null  float64
# dtypes: float64(5), int64(2), object(3)
# memory usage: 2.1+ MB

# %%
# df1_backup.info()

# %%
df["subsidy_level"].values
# Out:
# array([1, 1, 1, ..., 1, 1, 1], dtype=int64)

# %%
df1.columns
# Out:
# Index(['Date', 'country', 'region', 'income_level', 'subsidy_level',
#        'petrol_usd_liter', 'diesel_usd_liter', 'lpg_usd_liter',
#        'brent_crude_usd', 'tax_percentage'],
#       dtype='object')

# %%
df.dropna(subset=["Date"])
# Out:
#                       Date        country         region income_level  \
# 0      1578268800000000000  United States  North America         High
# 1      1578873600000000000  United States  North America         High
# 2      1579478400000000000  United States  North America         High
# 3      1580083200000000000  United States  North America         High
# 4      1580688000000000000  United States  North America         High
# ...                    ...            ...            ...          ...
# 27463  1773014400000000000         Rwanda         Africa          Low
# 27464  1773619200000000000         Rwanda         Africa          Low
# 27465  1774224000000000000         Rwanda         Africa          Low
# 27466  1774828800000000000         Rwanda         Africa          Low
# 27467  1775433600000000000         Rwanda         Africa          Low
#
#        subsidy_level  petrol_usd_liter  diesel_usd_liter  lpg_usd_liter  \
# ...

# %%
df1 = df1.drop(["subsidy_level", "Date"], axis=1)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27468 entries, 0 to 27467
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   country           27468 non-null  object
#  1   region            27468 non-null  object
#  2   income_level      27468 non-null  object
#  3   petrol_usd_liter  27468 non-null  float64
#  4   diesel_usd_liter  27468 non-null  float64
#  5   lpg_usd_liter     27468 non-null  float64
#  6   brent_crude_usd   27468 non-null  float64
#  7   tax_percentage    27468 non-null  float64
# dtypes: float64(5), object(3)
# memory usage: 1.7+ MB

# %%
# df1=df1.melt(id_vars=["Name"],value_vars=["math","science","English"],var_name="subject",value_name="score")

# %%
# df.pivot(index=None, columns=None, values=None )
